# %%
from sklearn.datasets import load_iris
dataset = load_iris()

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(dataset.data, dataset.target, test_size=0.2)

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100)

rf.fit(x_train, y_train)

print("Accuracy: {}".format(rf.score(x_test,y_test)))
# Out:
# Accuracy: 0.9333333333333333

# %% [markdown]
# # Save and Load Model using Pickle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle

# %%
with open("/content/drive/MyDrive/You tube machine learn/Machine Learning/Save and Load model/rf_model.pickle","wb") as file:
  pickle.dump(rf, file)

# %%
with open("/content/drive/MyDrive/You tube machine learn/Machine Learning/Save and Load model/rf_model.pickle","rb") as file:
  model1 = pickle.load(file)

# %%
model1
# Out:
# RandomForestClassifier()

# %%
SepalLength=6.3
SepalWidth=2.3
PetalLength=4.7
PetalWidth=1.3

model1.predict([[SepalLength,SepalWidth,PetalLength,PetalWidth]])
# Out:
# array([1])

# %% [markdown]
# # Save and Load model using Joblib

# %%
import joblib

# %%
joblib.dump(rf,"/content/drive/MyDrive/You tube machine learn/Machine Learning/Save and Load model/rf_model2.pickle")
# Out:
# ['/content/drive/MyDrive/You tube machine learn/Machine Learning/Save and Load model/rf_model2.pickle']

# %%
model2 = joblib.load("/content/drive/MyDrive/You tube machine learn/Machine Learning/Save and Load model/rf_model.pickle")

# %%
model2
# Out:
# RandomForestClassifier()

# %%
SepalLength=6.3
SepalWidth=2.3
PetalLength=4.7
PetalWidth=1.3

model2.predict([[SepalLength,SepalWidth,PetalLength,PetalWidth]])
# Out:
# array([1])
