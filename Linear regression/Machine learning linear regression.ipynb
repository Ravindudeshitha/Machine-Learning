# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('/content/drive/MyDrive/You tube machine learn/Linear regression/Book.csv')

# %%
data
# Out:
#   Unnamed: 0  videos  views
# 0   channel1      30  34000
# 1   channel2      40  41000
# 2   channel3      50  42500
# 3   channel4      60  54300
# 4   channel5      70  56000

# %%
plt.scatter(data.videos, data.views, color='red')
plt.xlabel('Videos')
plt.ylabel('views')
# Out:
# Text(0, 0.5, 'views')

# %%
data.views
# Out:
# 0    34000
# 1    41000
# 2    42500
# 3    54300
# 4    56000
# Name: views, dtype: int64

# %%
data.videos
# Out:
# 0    30
# 1    40
# 2    50
# 3    60
# 4    70
# Name: videos, dtype: int64

# %%
x = np.array(data.videos.values)
y = np.array(data.views.values)

# %%
model = LinearRegression()
model.fit(x.reshape(-1,1),y)
# Out:
# LinearRegression()

# %%
new_x = np.array([54]).reshape(-1,1)
new_x
# Out:
# array([[54]])

# %%
pred = model.predict(new_x)
pred
# Out:
# array([47852.])

# %%
plt.scatter(data.videos, data.views, color='red')
m,c = np.polyfit(x,y,1)
plt.plot(x,m*x+c)
plt.xlabel('Videos')
plt.ylabel('views')
# Out:
# Text(0, 0.5, 'views')

# %%
m
# Out:
# 573.0

# %%
c
# Out:
# 16910.000000000007

# %%
ynew = m * 45 + c
ynew
# Out:
# 42695.00000000001

# %%
data2 = pd.read_csv('/content/drive/MyDrive/You tube machine learn/Linear regression/Book2.csv')
data2
# Out:
#   Unnamed: 0  videos  days  subscribers  views
# 0  channel 1      30   150         1800  34000
# 1  channel 2      40   212         1950  41000
# 2  channel 3      50   179         2100  42500
# 3  channel 4      60   346         4300  54300
# 4  channel 5      70   280         4200  56000

# %%
model2 = LinearRegression()
model2.fit(data2[['videos', 'days', 'subscribers']], data.views)
# Out:
# LinearRegression()

# %%
model2.predict([[45,180, 3100]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41483.5043287])

# %%
model2.coef_
# Out:
# array([3.81732131e+02, 4.21209097e+01, 3.54006782e-01])

# %%
model2.intercept_
# Out:
# 15626.373669488294

# %%
yn = model2.coef_[0]*45 + model2.coef_[1]*180+ model2.coef_[2]*3100 + model2.intercept_
yn
# Out:
# 41483.504328703
